# %% [markdown]
# ## YouTube Video Transcripts and SEO Keywords Generation

# %% [markdown]
# - We will see how to generate YouTube video transcripts and SEO keywords using LLM

# %%
from youtube_transcript_api import (
                NoTranscriptFound,
                TranscriptsDisabled,
                YouTubeTranscriptApi,
)

# %%
# !pip install youtube-transcript-api pytube
# Out:
# Requirement already satisfied: youtube-transcript-api in /Users/andrestrepo/Documents/repos_personal/Langchain-and-Ollama/.venv/lib/python3.12/site-packages (0.6.2)
# Requirement already satisfied: pytube in /Users/andrestrepo/Documents/repos_personal/Langchain-and-Ollama/.venv/lib/python3.12/site-packages (15.0.0)
# Requirement already satisfied: requests in /Users/andrestrepo/Documents/repos_personal/Langchain-and-Ollama/.venv/lib/python3.12/site-packages (from youtube-transcript-api) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/andrestrepo/Documents/repos_personal/Langchain-and-Ollama/.venv/lib/python3.12/site-packages (from requests->youtube-transcript-api) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/andrestrepo/Documents/repos_personal/Langchain-and-Ollama/.venv/lib/python3.12/site-packages (from requests->youtube-transcript-api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/andrestrepo/Documents/repos_personal/Langchain-and-Ollama/.venv/lib/python3.12/site-packages (from requests->youtube-transcript-api) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/andrestrepo/Documents/repos_personal/Langchain-and-Ollama/.venv/lib/python3.12/site-packages (from requests->youtube-transcript-api) (2024.12.14)

# %%
from youtube_transcript_api import YouTubeTranscriptApi


transcript_list = YouTubeTranscriptApi.list_transcripts('qiLYxZZC5KA')
for t in transcript_list:
    print(t)
# Out:
# es ("Spanish (auto-generated)")[TRANSLATABLE]

# %%
transcript = transcript_list.find_transcript(['es'])

# %%
print(
    transcript.video_id,
    transcript.language,
    transcript.language_code,
    # whether it has been manually created or generated by YouTube
    transcript.is_generated,
    # whether this transcript can be translated or not
    transcript.is_translatable,
)
# Out:
# qiLYxZZC5KA Spanish (auto-generated) es True True

# %%
# or automatically generated ones
transcript = transcript_list.find_generated_transcript(['es'])

# %%
print(
    transcript.video_id,
    transcript.language,
    transcript.language_code,
    # whether it has been manually created or generated by YouTube
    transcript.is_generated,
    # whether this transcript can be translated or not
    transcript.is_translatable,
)
# Out:
# qiLYxZZC5KA Spanish (auto-generated) es True True

# %%
YouTubeTranscriptApi.get_transcript('qiLYxZZC5KA',languages=['es'])
# Out:
# [{'text': 'Saludos cordiales iniciamos hoy viernes',
#   'start': 0.599,
#   'duration': 5.921},
#  {'text': '31 de enero el último análisis del mes',
#   'start': 3.36,
#   'duration': 5.279},
#  {'text': 'para bitcoin para el resto de activos',
#   'start': 6.52,
#   'duration': 3.56},
#  {'text': 'etherium', 'start': 8.639, 'duration': 4.481},
#  {'text': 'xrp solana y echaremos un vistac ito',
#   'start': 10.08,
#   'duration': 6.0},
#  {'text': 'Cómo va la bolsa lo que nos van', 'start': 13.12, 'duration': 5.52},
#  {'text': 'adelantando los futuros del sp500 en',
#   'start': 16.08,
#   'duration': 3.6},
#  {'text': 'nasdaq', 'start': 18.64, 'duration': 4.879},
#  {'text': 'etcétera bueno en el día de ayer',
#   'start': 19.68,
#   'duration': 8.08},
#  {'text': 'la cotización de bitcoin nos dejó esta',
#   'start': 23.519,
#   'duration': 8.641},
#  {'text': 'referencia esa negociación de Vela con',
#   'start': 27.76,
#   'duration': 7.799},
#  {'text': 'el cierre vamos a colocarle otro color',
#   'start': 32.16,
#   'duration': 5.2},
#  {'text': 'por encima', 'start': 35.559, 'duration': 5.52},
#  {'text': 'del la directriz que tengo por aquí',
#   'start': 37.36,
#   'duration': 7.519},
#  {'text': 'uniendo el máximo anterior la rompió',
#   'start': 41.079,
#   'duration': 7.601},
#  {'text': 'cerró por arriba sin embargo la imagen',
#   'start': 44.879,
#   'duration': 7.16},
#  {'text': 'puede parecer de una señal de reversión',
#   'start': 48.68,
#   'duration': 6.16},
#  {'text': 'verdad que se tendría que confirmar',
#   'start': 52.039,
#   'duration': 5.921},
#  {'text': 'bueno no nos adelantemos demasiado en el',
#   'start': 54.84,
#   'duration': 4.08},
#  {'text': 'día de', 'start': 57.96, 'duration': 3.84},
#  {'text': 'hoy eh lo que ha sido en la sesión',
#   'start': 58.92,
#   'duration': 5.16},
#  {'text': 'asiática y en preapertura', 'start': 61.8, 'duration': 4.999},
#  {'text': 'europea Eh bueno el movimiento ha sido',
#   'start': 64.08,
#   'duration': 4.64},
#  {'text': 'bastante tímido pero siempre por encima',
#   'start': 66.799,
#   'duration': 5.041},
#  {'text': 'de esta directriz la vamos a estar eh la',
#   'start': 68.72,
#   'duration': 4.84},
#  {'text': 'vamos a dejar aquí marcada y la vamos a',
#   'start': 71.84,
#   'duration': 4.56},
#  {'text': 'vigilar durante la jornada porque es la',
#   'start': 73.56,
#   'duration': 5.48},
#  {'text': 'que tiene esa clave por otro lado si',
#   'start': 76.4,
#   'duration': 5.24},
#  {'text': 'miramos la semana le quedan ahora mismo',
#   'start': 79.04,
#   'duration': 5.399},
#  {'text': '2 días y 17 horas Pues seguimos viendo',
#   'start': 81.64,
#   'duration': 5.92},
#  {'text': 'este rebote en los 101,5', 'start': 84.439, 'duration': 5.801},
#  {'text': '75 cosas destacables', 'start': 87.56, 'duration': 6.239},
#  {'text': 'bueno máximos anteriores que han sido',
#   'start': 90.24,
#   'duration': 5.72},
#  {'text': 'testeados pero no han sido', 'start': 93.799, 'duration': 6.0},
#  {'text': 'rebasados bien la semana pasada nos dejó',
#   'start': 95.96,
#   'duration': 6.519},
#  {'text': 'esta señal de posible reversión esta',
#   'start': 99.799,
#   'duration': 4.64},
#  {'text': 'semana a pesar de que estamos viendo',
#   'start': 102.479,
#   'duration': 4.041},
#  {'text': 'cómo se han generado todas estas compras',
#   'start': 104.439,
#   'duration': 5.401},
#  {'text': 'en un objetivo de largo plazo para tomar',
#   'start': 106.52,
#   'duration': 6.199},
#  {'text': 'beneficios donde apenas se han tomado',
#   'start': 109.84,
#   'duration': 4.319},
#  {'text': 'esta', 'start': 112.719, 'duration': 7.44},
#  {'text': 'semana esta y también esta eh', 'start': 114.159, 'duration': 7.92},
#  {'text': 'no significa que el precio vaya ya',
#   'start': 120.159,
#   'duration': 3.841},
#  {'text': 'directamente a 109', 'start': 122.079, 'duration': 5.121},
#  {'text': '112 vamos a esperar esos dos días y 17',
#   'start': 124.0,
#   'duration': 6.2},
#  {'text': 'horas porque un cierre nuevamente por',
#   'start': 127.2,
#   'duration': 5.96},
#  {'text': 'encima de este nivel podría propiciar',
#   'start': 130.2,
#   'duration': 6.28},
#  {'text': 'que a un precio más caro fíjense ustedes',
#   'start': 133.16,
#   'duration': 5.079},
#  {'text': 'que ahora mismo Está en', 'start': 136.48, 'duration': 7.2},
#  {'text': '104000 eh 10600 un precio más caro todos',
#   'start': 138.239,
#   'duration': 8.041},
#  {'text': 'aquellos que todavía no han realizado',
#   'start': 143.68,
#   'duration': 4.72},
#  {'text': 'sus ventas para tomar beneficios y',
#   'start': 146.28,
#   'duration': 4.64},
#  {'text': 'comprar a un precio más bajo', 'start': 148.4, 'duration': 4.64},
#  {'text': 'lo podrían hacer después de este cierre',
#   'start': 150.92,
#   'duration': 4.36},
#  {'text': 'semanal entonces a la hora de tomar',
#   'start': 153.04,
#   'duration': 4.32},
#  {'text': 'decisiones Tenemos que tener esto en',
#   'start': 155.28,
#   'duration': 5.8},
#  {'text': 'cuenta lo mismo que esta señal que nos',
#   'start': 157.36,
#   'duration': 6.959},
#  {'text': 'quedó en el día de ayer es un reteste de',
#   'start': 161.08,
#   'duration': 6.04},
#  {'text': 'toda esta zona tengamos esto en cuenta',
#   'start': 164.319,
#   'duration': 5.041},
#  {'text': 'también toda esta zona de precios yo',
#   'start': 167.12,
#   'duration': 3.52},
#  {'text': 'siempre aquí quiero', 'start': 169.36, 'duration': 3.23},
#  {'text': 'hacer', 'start': 170.64, 'duration': 3.16},
#  {'text': '[Música]', 'start': 172.59, 'duration': 4.929},
#  {'text': 'un un inciso no sino quiero hacer',
#   'start': 173.8,
#   'duration': 5.4},
#  {'text': 'bastante fuerza en que se den cuenta de',
#   'start': 177.519,
#   'duration': 4.841},
#  {'text': 'que no estamos mirando un cuadro no',
#   'start': 179.2,
#   'duration': 6.52},
#  {'text': 'estamos intentando interpretar algo',
#   'start': 182.36,
#   'duration': 5.599},
#  {'text': 'abstracto sino que tiene bastantes',
#   'start': 185.72,
#   'duration': 3.879},
#  {'text': 'sentido porque son precios donde nos',
#   'start': 187.959,
#   'duration': 4.64},
#  {'text': 'estamos moviendo si nosotros cogemos por',
#   'start': 189.599,
#   'duration': 5.64},
#  {'text': 'ejemplo y nos venimos a ver la misma',
#   'start': 192.599,
#   'duration': 5.92},
#  {'text': 'cotización del mismo exchange de bitcoin',
#   'start': 195.239,
#   'duration': 4.121},
#  {'text': 'dóllar', 'start': 198.519, 'duration': 4.0},
#  {'text': 'en por ejemplo en investing que me gusta',
#   'start': 199.36,
#   'duration': 4.519},
#  {'text': 'mucho sus datos', 'start': 202.519, 'duration': 3.8},
#  {'text': 'históricos Bueno aquí estamos viendo el',
#   'start': 203.879,
#   'duration': 5.161},
#  {'text': 'gráfico lineal ya solamente con que',
#   'start': 206.319,
#   'duration': 4.56},
#  {'text': 'digamos un gráfico lineal tenemos',
#   'start': 209.04,
#   'duration': 4.52},
#  {'text': 'muchísima información a nuestra vista',
#   'start': 210.879,
#   'duration': 5.121},
#  {'text': 'nos va diciendo Cómo se ha estado',
#   'start': 213.56,
#   'duration': 3.92},
#  {'text': 'moviendo aquí estamos en un gráfico de',
#   'start': 216.0,
#   'duration': 3.92},
#  {'text': '15 minutos la cotización en este tiempo',
#   'start': 217.48,
#   'duration': 4.319},
#  {'text': 'pero no me interesa esa parte me',
#   'start': 219.92,
#   'duration': 4.879},
#  {'text': 'interesa la serie diaria y vemos',
#   'start': 221.799,
#   'duration': 6.401},
#  {'text': 'perfectamente Cómo desde desde octubre',
#   'start': 224.799,
#   'duration': 5.881},
#  {'text': 'noviembre del año pasado ya después a',
#   'start': 228.2,
#   'duration': 4.64},
#  {'text': 'partir de la mitad de diciembre no se ha',
#   'start': 230.68,
#   'duration': 3.72},
#  {'text': 'movido De esta zona que nosotros tenemos',
#   'start': 232.84,
#   'duration': 3.8},
#  {'text': 'delimitada con los objetivos de largo y',
#   'start': 234.4,
#   'duration': 4.64},
#  {'text': 'de mediano plazo donde se está tomando',
#   'start': 236.64,
#   'duration': 4.04},
#  {'text': 'beneficios pero tampoco quiero llegar a',
#   'start': 239.04,
#   'duration': 4.32},
#  {'text': 'eso quiero que veamos que la diferencia',
#   'start': 240.68,
#   'duration': 5.36},
#  {'text': 'entre estar observando el gráfico',
#   'start': 243.36,
#   'duration': 7.04},
#  {'text': 'eh Estableciendo zonas donde el precio',
#   'start': 246.04,
#   'duration': 7.119},
#  {'text': 'vamos a hacerlo en la serie diaria Don',
#   'start': 250.4,
#   'duration': 4.8},
#  {'text': 'lo que yo les comentaba hace un momento',
#   'start': 253.159,
#   'duration': 3.64},
#  {'text': 'esta zona de', 'start': 255.2, 'duration': 4.879},
#  {'text': 'máximos que se ha vuelto a r testear',
#   'start': 256.799,
#   'duration': 4.921},
#  {'text': 'todo esto tiene un sentido porque son',
#   'start': 260.079,
#   'duration': 4.641},
#  {'text': 'precios no estamos viendo un cuadro lo',
#   'start': 261.72,
#   'duration': 7.56},
#  {'text': 'que estamos mirando es la cotización en',
#   'start': 264.72,
#   'duration': 5.52},
#  {'text': 'constante', 'start': 269.28, 'duration': 3.68},
#  {'text': 'movimiento si nos venimos a la', 'start': 270.24, 'duration': 4.72},
#  {'text': 'información', 'start': 272.96, 'duration': 4.32},
#  {'text': 'histórica y lo mismo que estamos viendo',
#   'start': 274.96,
#   'duration': 6.679},
#  {'text': 'en forma de velas lo miramos con un',
#   'start': 277.28,
#   'duration': 7.6},
#  {'text': 'precio exacto de apertura un máximo un',
#   'start': 281.639,
#   'duration': 8.521},
#  {'text': 'mínimo y un cierre mirando todo eso Si',
#   'start': 284.88,
#   'duration': 6.96},
#  {'text': 'nosotros eso lo llevamos una Excel y lo',
#   'start': 290.16,
#   'duration': 3.64},
#  {'text': 'estudiamos vamos a', 'start': 291.84, 'duration': 4.919},
#  {'text': 'determinar Cuántos días lleva sin que se',
#   'start': 293.8,
#   'duration': 6.04},
#  {'text': 'rompa unos máximos vamos a determinar',
#   'start': 296.759,
#   'duration': 6.361},
#  {'text': 'también que se ha estado testeando esos',
#   'start': 299.84,
#   'duration': 6.48},
#  {'text': 'máximos sin que haya un cierre por',
#   'start': 303.12,
#   'duration': 6.799},
#  {'text': 'encima un cierre por encima de esos',
#   'start': 306.32,
#   'duration': 5.879},
#  {'text': 'máximos que hemos estado testeando esto',
#   'start': 309.919,
#   'duration': 4.601},
#  {'text': 'lo lleva uno es lo que yo hacía desde',
#   'start': 312.199,
#   'duration': 4.84},
#  {'text': 'desde muy bastante más joven', 'start': 314.52, 'duration': 5.76},
#  {'text': 'e y fueron mis inicios porque nosotros',
#   'start': 317.039,
#   'duration': 5.681},
#  {'text': 'solo teníamos información una vez al día',
#   'start': 320.28,
#   'duration': 4.16},
#  {'text': 'ayer lo decía en el Canal de bolsa',
#   'start': 322.72,
#   'duration': 4.319},
#  {'text': 'mientras me Toa un café en ese coffee',
#   'start': 324.44,
#   'duration': 5.64},
#  {'text': 'break haciendo una reflexión todo ese',
#   'start': 327.039,
#   'duration': 5.801},
#  {'text': 'ruido de Mercado antes solo teníamos',
#   'start': 330.08,
#   'duration': 4.839},
#  {'text': 'esta información una vez al día ahora',
#   'start': 332.84,
#   'duration': 4.44},
#  {'text': 'cada vez que miras el móvil ya te salta',
#   'start': 334.919,
#   'duration': 6.601},
#  {'text': 'ahí una alerta información globos de',
#   'start': 337.28,
#   'duration': 6.52},
#  {'text': 'diferentes que s de to exchange que s',
#   'start': 341.52,
#   'duration': 5.44},
#  {'text': 'investing informándonos todo el tiempo y',
#   'start': 343.8,
#   'duration': 7.32},
#  {'text': 'eso nos lleva o a sobre operar a estar',
#   'start': 346.96,
#   'duration': 5.6},
#  {'text': 'muy pendiente de los mercados antes',
#   'start': 351.12,
#   'duration': 3.28},
#  {'text': 'solamente teníamos esto y con esto',
#   'start': 352.56,
#   'duration': 5.28},
#  {'text': 'establecí muy bien eh Todo lo que estaba',
#   'start': 354.4,
#   'duration': 5.519},
#  {'text': 'pasando con el movimiento del precio Por',
#   'start': 357.84,
#   'duration': 4.479},
#  {'text': 'eso digo que si lo vamos estudiando',
#   'start': 359.919,
#   'duration': 4.521},
#  {'text': 'vemos Que sí que el máximo que dejó el',
#   'start': 362.319,
#   'duration': 4.401},
#  {'text': '17 de enero cuando llegó al objetivo de',
#   'start': 364.44,
#   'duration': 3.52},
#  {'text': 'mediano plazo y se están tomando',
#   'start': 366.72,
#   'duration': 3.28},
#  {'text': 'beneficios lo testea pero cada vez que',
#   'start': 367.96,
#   'duration': 3.04},
#  {'text': 'lo', 'start': 370.0, 'duration': 5.039},
#  {'text': 'testea el precio cae tiene que romper',
#   'start': 371.0,
#   'duration': 7.16},
#  {'text': 'esta zona vamos a determinarla esta zona',
#   'start': 375.039,
#   'duration': 4.841},
#  {'text': 'de precios Pero esto Igualmente lo',
#   'start': 378.16,
#   'duration': 5.439},
#  {'text': 'podíamos haber hecho en una en una exel',
#   'start': 379.88,
#   'duration': 6.52},
#  {'text': 'y esas referenci son los', 'start': 383.599, 'duration': 5.681},
#  {'text': '10593 Entonces es muy importante saber',
#   'start': 386.4,
#   'duration': 6.32},
#  {'text': 'que no ha podido superar ese nivel',
#   'start': 389.28,
#   'duration': 6.44},
#  {'text': 'evidentemente se puede comprar para ir',
#   'start': 392.72,
#   'duration': 6.08},
#  {'text': 'de los 101,5 75 como yo decía objetivos',
#   'start': 395.72,
#   'duration': 7.56},
#  {'text': 'semanales alcistas tenemos los 108 los',
#   'start': 398.8,
#   'duration': 4.48},
#  {'text': '10976 pero hay que tener en cuenta que',
#   'start': 403.639,
#   'duration': 5.0},
#  {'text': 'hay que romper la Barrera de los',
#   'start': 406.039,
#   'duration': 6.801},
#  {'text': '10593 y que todavía todavía no tiene voy',
#   'start': 408.639,
#   'duration': 6.12},
#  {'text': 'a dejar lo que no se vea Bueno vamos a',
#   'start': 412.84,
#   'duration': 4.199},
#  {'text': 'mirarlo un momentito en la serie semanal',
#   'start': 414.759,
#   'duration': 7.081},
#  {'text': 'porque es este este máximo de la',
#   'start': 417.039,
#   'duration': 4.801},
#  {'text': 'semana que está por aquí sobre la zona',
#   'start': 422.12,
#   'duration': 4.919},
#  {'text': 'de los 108000 que tenemos marcado',
#   'start': 424.919,
#   'duration': 6.481},
#  {'text': 'delimitado verdad pues es importante',
#   'start': 427.039,
#   'duration': 8.041},
#  {'text': 'saber que vamos a encontrarnos con esta',
#   'start': 431.4,
#   'duration': 5.479},
#  {'text': 'zona nueva de', 'start': 435.08, 'duration': 4.16},
#  {'text': 'distribución con ese máximo junto con',
#   'start': 436.879,
#   'duration': 4.521},
#  {'text': 'los', 'start': 439.24, 'duration': 2.16},
#  {'text': '10765 entonces por eso la acción del',
#   'start': 443.24,
#   'duration': 4.72},
#  {'text': 'precio es tan importante sobre todo si',
#   'start': 446.24,
#   'duration': 5.16},
#  {'text': 'sabemos calcular los Ob', 'start': 447.96, 'duration': 5.959},
#  {'text': 'porque si no evidentemente vamos a estar',
#   'start': 451.4,
#   'duration': 6.68},
#  {'text': 'bastante perdidos y esto esto que acabo',
#   'start': 453.919,
#   'duration': 8.12},
#  {'text': 'de apagar y encender esto nació hace',
#   'start': 458.08,
#   'duration': 6.679},
#  {'text': 'muchísimos años desde esta otra parte Yo',
#   'start': 462.039,
#   'duration': 5.321},
#  {'text': 'lo he explicado numerosas veces aquí en',
#   'start': 464.759,
#   'duration': 3.761},
#  {'text': 'el', 'start': 467.36, 'duration': 4.0},
#  {'text': 'canal por eso en vez de estar buscando',
#   'start': 468.52,
#   'duration': 4.72},
#  {'text': 'figuras de chartismo', 'start': 471.36, 'duration': 4.559},
#  {'text': 'eh algo que nos suene que haya pasado en',
#   'start': 473.24,
#   'duration': 4.679},
#  {'text': 'el pasado para predecir lo que va a',
#   'start': 475.919,
#   'duration': 3.56},
#  {'text': 'pasar en el futuro si nos centramos',
#   'start': 477.919,
#   'duration': 3.921},
#  {'text': 'Dónde está el precio y qu está haciendo',
#   'start': 479.479,
#   'duration': 5.0},
#  {'text': 'nos puede dar más', 'start': 481.84, 'duration': 6.52},
#  {'text': 'pistas un poquito adelantado nada más',
#   'start': 484.479,
#   'duration': 6.041},
#  {'text': 'Pero sobre todo lo que nos va a dar son',
#   'start': 488.36,
#   'duration': 5.44},
#  {'text': 'proyecciones para tener un plan Qué pasa',
#   'start': 490.52,
#   'duration': 5.28},
#  {'text': 'si yo he decidido que el precio está',
#   'start': 493.8,
#   'duration': 3.44},
#  {'text': 'rompiendo esta zona pues quiero', 'start': 495.8, 'duration': 3.48},
#  {'text': 'aprovechar y comprar para ir a los',
#   'start': 497.24,
#   'duration': 4.6},
#  {'text': '109,000 pero tengo que tener en plan',
#   'start': 499.28,
#   'duration': 4.759},
#  {'text': 'previsto Qué pasa aquí en los', 'start': 501.84, 'duration': 5.56},
#  {'text': '10900 venderé o compraré a partir de',
#   'start': 504.039,
#   'duration': 5.961},
#  {'text': 'aquí para ello bajamos a la serie de 4',
#   'start': 507.4,
#   'duration': 4.639},
#  {'text': 'horas y esos', 'start': 510.0, 'duration': 5.76},
#  {'text': '105000 esa zona viene estando por aquí',
#   'start': 512.039,
#   'duration': 6.36},
#  {'text': 'por esta de de máximos previo está',
#   'start': 515.76,
#   'duration': 4.719},
#  {'text': 'estamos hablando de esta de aquí a la',
#   'start': 518.399,
#   'duration': 4.481},
#  {'text': 'izquierda voy ponerlo un poquito más acá',
#   'start': 520.479,
#   'duration': 4.321},
#  {'text': 'está por encima de mí aquí a la',
#   'start': 522.88,
#   'duration': 3.84},
#  {'text': 'izquierda estos son los', 'start': 524.8, 'duration': 5.68},
#  {'text': '10593 este cierre del 17 de enero Este',
#   'start': 526.72,
#   'duration': 6.239},
#  {'text': 'es el que nos lo va marcando Vale',
#   'start': 530.48,
#   'duration': 4.84},
#  {'text': 'entonces fíjense que si trazamos una',
#   'start': 532.959,
#   'duration': 6.481},
#  {'text': 'línea desde aquí desde ese Cierre en el',
#   'start': 535.32,
#   'duration': 6.639},
#  {'text': 'gráfico de 4 horas miren como', 'start': 539.44, 'duration': 5.079},
#  {'text': 'efectivamente cuando llega está',
#   'start': 541.959,
#   'duration': 4.44},
#  {'text': 'determinando ese', 'start': 544.519, 'duration': 5.0},
#  {'text': 'máximo lo están aprovechando todos',
#   'start': 546.399,
#   'duration': 5.161},
#  {'text': 'aquellos especuladores', 'start': 549.519, 'duration': 4.841},
#  {'text': 'que trabajan con máximos y con mínimos',
#   'start': 551.56,
#   'duration': 5.719},
#  {'text': 'que es una muy buena forma razonable de',
#   'start': 554.36,
#   'duration': 6.0},
#  {'text': 'operar sin A lo mejor saber calcular',
#   'start': 557.279,
#   'duration': 7.081},
#  {'text': 'eh los niveles objetivos Pero saben',
#   'start': 560.36,
#   'duration': 6.08},
#  {'text': 'utilizar muy bien los máximos y los',
#   'start': 564.36,
#   'duration': 4.24},
#  {'text': 'mínimos para comprar y para vender',
#   'start': 566.44,
#   'duration': 4.28},
#  {'text': 'Entonces', 'start': 568.6, 'duration': 5.28},
#  {'text': 'Ayer por la tarde en el último análisis',
#   'start': 570.72,
#   'duration': 7.2},
#  {'text': 'les decía ha nacido una fase alcista se',
#   'start': 573.88,
#   'duration': 6.519},
#  {'text': 'ha colocado en la zona de los', 'start': 577.92, 'duration': 5.919},
#  {'text': '10923 que es el 6180 de la corrección de',
#   'start': 580.399,
#   'duration': 5.921},
#  {'text': 'la fase anterior es una zona de compras',
#   'start': 583.839,
#   'duration': 4.0},
#  {'text': 'donde se puede abrir la puerta a las',
#   'start': 586.32,
#   'duration': 4.8},
#  {'text': 'compras para ir a visitar los 109000 Y',
#   'start': 587.839,
#   'duration': 4.801},
#  {'text': 'cerrar allí', 'start': 591.12, 'duration': 4.6},
#  {'text': 'posiciones pero ahora fíjense ustedes',
#   'start': 592.64,
#   'duration': 5.8},
#  {'text': 'cómo vamos a colocarlo exactamente son',
#   'start': 595.72,
#   'duration': 5.6},
#  {'text': '105000 900', 'start': 598.44, 'duration': 4.48},
#  {'text': 'eh', 'start': 601.32, 'duration': 5.44},
#  {'text': '32 vamos a dejarlo', 'start': 602.92, 'duration': 6.24},
#  {'text': 'colocado porque esto es lo que hace uno',
#   'start': 606.76,
#   'duration': 5.16},
#  {'text': 'en premercado Para que', 'start': 609.16, 'duration': 5.32},
#  {'text': 'vean lo importante que es esta', 'start': 611.92, 'duration': 5.84},
#  {'text': 'referencia de este máximo previo si yo',
#   'start': 614.48,
#   'duration': 4.919},
#  {'text': 'tuviera que tomar una determinación ayer',
#   'start': 617.76,
#   'duration': 3.48},
#  {'text': 'les decía cuando estábamos por aquí',
#   'start': 619.399,
#   'duration': 4.401},
#  {'text': 'todavía el preseo no había ni caído yo',
#   'start': 621.24,
#   'duration': 5.56},
#  {'text': 'no a pesar de que sea una zona donde se',
#   'start': 623.8,
#   'duration': 6.56},
#  {'text': 'puede dar una señal hay otra cosas que a',
#   'start': 626.8,
#   'duration': 6.56},
#  {'text': 'mí no me permiten en mi estrategia Si yo',
#   'start': 630.36,
#   'duration': 5.0},
#  {'text': 'fuera ahora mismo a corto', 'start': 633.36, 'duration': 5.24},
#  {'text': 'plazo no me permiten operarla porque no',
#   'start': 635.36,
#   'duration': 6.039},
#  {'text': 'le puedo dar ese check de que están',
#   'start': 638.6,
#   'duration': 5.4},
#  {'text': 'sucediendo en todo caso para ello',
#   'start': 641.399,
#   'duration': 4.161},
#  {'text': 'tendría que ser que se colocara el',
#   'start': 644.0,
#   'duration': 3.56},
#  {'text': 'precio por encima de esta', 'start': 645.56, 'duration': 5.2},
#  {'text': 'zona poniéndose por encima de esta zona',
#   'start': 647.56,
#   'duration': 6.04},
#  {'text': 'cerrando por aquí y que', 'start': 650.76, 'duration': 6.36},
#  {'text': 'yo vea ya que se me va', 'start': 653.6, 'duration': 6.2},
#  {'text': 'abriendo la puerta la estrategia',
#   'start': 657.12,
#   'duration': 5.399},
#  {'text': 'que se vaya cumpliendo el evento sería',
#   'start': 659.8,
#   'duration': 5.32},
#  {'text': 'donde tomaría esa decisión pero no aquí',
#   'start': 662.519,
#   'duration': 4.44},
#  {'text': 'porque fíjense ustedes que en cuanto',
#   'start': 665.12,
#   'duration': 4.56},
#  {'text': 'ayer la testeo el precio cayó voy a',
#   'start': 666.959,
#   'duration': 4.88},
#  {'text': 'bajar un momentito a una hora pero vamos',
#   'start': 669.68,
#   'duration': 3.959},
#  {'text': 'a olvidarnos de los niveles intradiarias',
#   'start': 671.839,
#   'duration': 4.521},
#  {'text': 'Por un segundo porque no quiero que',
#   'start': 673.639,
#   'duration': 6.76},
#  {'text': 'estén involucrados aquí nos no nos dejen',
#   'start': 676.36,
#   'duration': 6.36},
#  {'text': 'miren en una hora lo que ocurre cuando',
#   'start': 680.399,
#   'duration': 4.24},
#  {'text': 'llega es', 'start': 682.72, 'duration': 5.84},
#  {'text': '10932 como lo devuelve a los 6180 si',
#   'start': 684.639,
#   'duration': 4.801},
#  {'text': 'hubiésemos', 'start': 688.56, 'duration': 2.719},
#  {'text': 'ad la determinación de comprar aquí',
#   'start': 689.44,
#   'duration': 4.28},
#  {'text': 'directamente colocando un stop muy',
#   'start': 691.279,
#   'duration': 6.24},
#  {'text': 'ajustado con esta con esta fuerte vela',
#   'start': 693.72,
#   'duration': 5.559},
#  {'text': 'decidida que yo les', 'start': 697.519, 'duration': 4.161},
#  {'text': 'comentaba trampa alcista intr diaria',
#   'start': 699.279,
#   'duration': 5.321},
#  {'text': 'evidentemente quedó como trampa alcista',
#   'start': 701.68,
#   'duration': 5.12},
#  {'text': 'a pesar de eso yo les decía ayer por la',
#   'start': 704.6,
#   'duration': 3.919},
#  {'text': 'tarde aquí no veo Esa evidencia de',
#   'start': 706.8,
#   'duration': 3.68},
#  {'text': 'compras Pues ahí lo', 'start': 708.519, 'duration': 5.0},
#  {'text': 'tienen si uno coloca el Stop Aquí muy',
#   'start': 710.48,
#   'duration': 5.479},
#  {'text': 'ajustado para ir pues ya ven que han',
#   'start': 713.519,
#   'duration': 6.361},
#  {'text': 'venido a hacer ese testeo ahora hoy que',
#   'start': 715.959,
#   'duration': 5.521},
#  {'text': 'ya va bajando la liquidez pero no hay',
#   'start': 719.88,
#   'duration': 5.28},
#  {'text': 'que sacar una conclusión ya con porque',
#   'start': 721.48,
#   'duration': 6.44},
#  {'text': 'sea viernes y haya menos participantes',
#   'start': 725.16,
#   'duration': 4.6},
#  {'text': 'ya las cosas se empiezan a preparar de',
#   'start': 727.92,
#   'duration': 3.44},
#  {'text': 'cara al fin de semana es el último día',
#   'start': 729.76,
#   'duration': 4.519},
#  {'text': 'del mes podíamos sacar conclusiones hay',
#   'start': 731.36,
#   'duration': 4.88},
#  {'text': 'menos participantes es el último día del',
#   'start': 734.279,
#   'duration': 4.481},
#  {'text': 'mes muchos van a', 'start': 736.24, 'duration': 5.88},
#  {'text': 'vender sería unas conclusiones así pero',
#   'start': 738.76,
#   'duration': 6.079},
#  {'text': 'no lo podemos dar por hecho eso no es',
#   'start': 742.12,
#   'duration': 4.88},
#  {'text': 'eso no es ninguna', 'start': 744.839, 'duration': 5.0},
#  {'text': 'estadística de hecho generan muchas',
#   'start': 747.0,
#   'duration': 5.36},
#  {'text': 'compras entre el último día y el primero',
#   'start': 749.839,
#   'duration': 4.081},
#  {'text': 'porque se van tomando determinaciones',
#   'start': 752.36,
#   'duration': 3.24},
#  {'text': 'por ejemplo hoy es el día que lo voy a',
#   'start': 753.92,
#   'duration': 3.52},
#  {'text': 'contar luego en el Canal de bolsas donde',
#   'start': 755.6,
#   'duration': 5.76},
#  {'text': 'yo ya determino para incorporar a mi',
#   'start': 757.44,
#   'duration': 8.36},
#  {'text': 'cartera cosas nuevas en en ella y es',
#   'start': 761.36,
#   'duration': 6.2},
#  {'text': 'precisamente porque es el último día del',
#   'start': 765.8,
#   'duration': 4.96},
#  {'text': 'mes Bueno pues miren ustedes esta imagen',
#   'start': 767.56,
#   'duration': 7.36},
#  {'text': 'Entonces yo no no vería eso Cuál es la',
#   'start': 770.76,
#   'duration': 7.28},
#  {'text': 'siguiente cosa que tengo que ver pues',
#   'start': 774.92,
#   'duration': 4.919},
#  {'text': 'que este', 'start': 778.04, 'duration': 4.919},
#  {'text': 'aquí tiene los los', 'start': 779.839, 'duration': 5.481},
#  {'text': '10714 que también es un', 'start': 782.959, 'duration': 3.921},
#  {'text': 'máximo', 'start': 785.32, 'duration': 4.24},
#  {'text': 'importante se iba a encontrar con este',
#   'start': 786.88,
#   'duration': 5.639},
#  {'text': 'Pero porque es la zona donde ha estado',
#   'start': 789.56,
#   'duration': 4.639},
#  {'text': 'haciendo estos máximos', 'start': 792.519, 'duration': 4.0},
#  {'text': 'previos pero si se coloca por encima de',
#   'start': 794.199,
#   'duration': 4.921},
#  {'text': 'todo esto Entonces sí que podría ya el',
#   'start': 796.519,
#   'duration': 5.361},
#  {'text': 'precio progresar Se podrían animar más',
#   'start': 799.12,
#   'duration': 5.04},
#  {'text': 'participantes para el corto plazo o el',
#   'start': 801.88,
#   'duration': 3.8},
#  {'text': 'muy corto porque esto ya sería incluso',
#   'start': 804.16,
#   'duration': 4.96},
#  {'text': 'muy corto podría precipitarse las',
#   'start': 805.68,
#   'duration': 4.76},
#  {'text': 'compras para ir a los', 'start': 809.12, 'duration': 4.12},
#  {'text': '109,000 mientras eso no suceda',
#   'start': 810.44,
#   'duration': 5.839},
#  {'text': 'complicado va a ser Seguimos estando en',
#   'start': 813.24,
#   'duration': 5.399},
#  {'text': 'una zona ramplona donde se está',
#   'start': 816.279,
#   'duration': 5.281},
#  {'text': 'distribuyendo Aparentemente salen',
#   'start': 818.639,
#   'duration': 5.601},
#  {'text': 'compras Pero no están yendo a ningún',
#   'start': 821.56,
#   'duration': 6.36},
#  {'text': 'lado bueno en todo esto decimos niveles',
#   'start': 824.24,
#   'duration': 5.92},
#  {'text': 'intr diarios Hay posibilidades de que el',
#   'start': 827.92,
#   'duration': 4.599},
#  {'text': 'precio se sitúe aquí e incluso que rompa',
#   'start': 830.16,
#   'duration': 4.16},
#  {'text': 'esto sabemos que los niveles intr',
#   'start': 832.519,
#   'duration': 3.921},
#  {'text': 'diarios son el cálculo de los que',
#   'start': 834.32,
#   'duration': 3.639},
#  {'text': 'negociadores los negociadores intr',
#   'start': 836.44,
#   'duration': 5.56},
#  {'text': 'diarios no van eh a lo loco cada día a',
#   'start': 837.959,
#   'duration': 7.921},
#  {'text': 'lo que venga voy a cerrar pues ahí',
#   'start': 842.0,
#   'duration': 6.519},
#  {'text': 'arriba cuando se me ocurra voy a esperar',
#   'start': 845.88,
#   'duration': 4.399},
#  {'text': 'un cruce de medias voy a esperar que el',
#   'start': 848.519,
#   'duration': 3.961},
#  {'text': 'oscilador se meta en la zona de',
#   'start': 850.279,
#   'duration': 4.641},
#  {'text': 'sobrecompra No es', 'start': 852.48, 'duration': 6.479},
#  {'text': 'eso es un promedio calculado cada día y',
#   'start': 854.92,
#   'duration': 5.359},
#  {'text': 'ayer vieron por ejemplo que en cuanto',
#   'start': 858.959,
#   'duration': 4.24},
#  {'text': 'llegó al último el precio empezó la',
#   'start': 860.279,
#   'duration': 4.92},
#  {'text': 'distribución y además caía por esta zona',
#   'start': 863.199,
#   'duration': 4.2},
#  {'text': 'de Máximo', 'start': 865.199, 'duration': 4.921},
#  {'text': 'bien hoy de hecho le podemos dar un',
#   'start': 867.399,
#   'duration': 4.401},
#  {'text': 'poquito para atrás a la reproducción y',
#   'start': 870.12,
#   'duration': 5.079},
#  {'text': 'automáticamente me lo va a recalcular',
#   'start': 871.8,
#   'duration': 6.12},
#  {'text': 'ayer le tenía que haber dado un poquito',
#   'start': 875.199,
#   'duration': 6.401},
#  {'text': 'más vamos a hacerlo ahora sí ven último',
#   'start': 877.92,
#   'duration': 4.599},
#  {'text': 'nivel', 'start': 881.6, 'duration': 3.56},
#  {'text': '10843 de ayer cuando cierra el precio',
#   'start': 882.519,
#   'duration': 3.32},
#  {'text': 'por', 'start': 885.16, 'duration': 4.479},
#  {'text': 'encima voy a ver si se los puedo mostrar',
#   'start': 885.839,
#   'duration': 6.721},
#  {'text': 'ahí en cuanto cierra por encima',
#   'start': 889.639,
#   'duration': 6.401},
#  {'text': 'automáticamente vemos que ya se',
#   'start': 892.56,
#   'duration': 5.839},
#  {'text': 'distribuye Esto fue lo que fue pasando',
#   'start': 896.04,
#   'duration': 5.4},
#  {'text': 'en el el día de ayer vamos a dejar que',
#   'start': 898.399,
#   'duration': 6.321},
#  {'text': 'vaya pasando las horas y ahora estamos',
#   'start': 901.44,
#   'duration': 5.0},
#  {'text': 'con este nuevo cálculo intradiario',
#   'start': 904.72,
#   'duration': 3.239},
#  {'text': 'Entonces el eje central de operaciones',
#   'start': 906.44,
#   'duration': 2.92},
#  {'text': 'están los', 'start': 907.959, 'duration': 4.8},
#  {'text': '10737 si yo voy si yo considerara',
#   'start': 909.36,
#   'duration': 6.64},
#  {'text': 'negociar intr diarios tiene que superar',
#   'start': 912.759,
#   'duration': 5.08},
#  {'text': 'los 104000 es el eje central de',
#   'start': 916.0,
#   'duration': 3.959},
#  {'text': 'operaciones los', 'start': 917.839, 'duration': 4.521},
#  {'text': '10923 y aquí me encuentro un primer',
#   'start': 919.959,
#   'duration': 7.401},
#  {'text': 'objetivo si viendo que el el precio del',
#   'start': 922.36,
#   'duration': 7.64},
#  {'text': 'O sea que consigue', 'start': 927.36, 'duration': 5.08},
#  {'text': 'compras aquí bastantes compras entre los',
#   'start': 930.0,
#   'duration': 6.36},
#  {'text': '104,900 y los 105100 estos dos niveles',
#   'start': 932.44,
#   'duration': 6.199},
#  {'text': 'entonces a partir de aquí podría decir',
#   'start': 936.36,
#   'duration': 5.2},
#  {'text': 'muy bien puedo ir a los', 'start': 938.639, 'duration': 4.601},
#  {'text': '10784', 'start': 941.56, 'duration': 5.92},
#  {'text': '106308 el último nivel está en los',
#   'start': 943.24,
#   'duration': 4.24},
#  {'text': '10832 Esta es la negociación intradiario',
#   'start': 948.6,
#   'duration': 5.799},
#  {'text': 'si se pone alcista el día de hoy',
#   'start': 951.639,
#   'duration': 5.56},
#  {'text': 'entonces la zona donde estábamos',
#   'start': 954.399,
#   'duration': 5.201},
#  {'text': 'estipulando una zona', 'start': 957.199, 'duration': 4.44},
#  {'text': 'donde ya se cumplen a mí se me cumplen',
#   'start': 959.6,
#   'duration': 4.08},
#  {'text': 'más reglas una zona que parece aquí',
#   'start': 961.639,
#   'duration': 3.521},
#  {'text': 'nunca hay seguridad pero vamos a decir',
#   'start': 963.68,
#   'duration': 4.24},
#  {'text': 'más segura sin que esto sea ningún tipo',
#   'start': 965.16,
#   'duration': 5.52},
#  {'text': 'de señal estoy explicando el mercado',
#   'start': 967.92,
#   'duration': 5.279},
#  {'text': 'desde el punto de vista educativo no no',
#   'start': 970.68,
#   'duration': 3.92},
#  {'text': 'estamos aquí haciendo un análisis para',
#   'start': 973.199,
#   'duration': 5.241},
#  {'text': 'que deci decidan ustedes comprar ni nada',
#   'start': 974.6,
#   'duration': 8.719},
#  {'text': 'parecido ya nos conocemos 106308 10832',
#   'start': 978.44,
#   'duration': 7.12},
#  {'text': 'Oye pues si cuando yo decido que esta',
#   'start': 983.319,
#   'duration': 4.841},
#  {'text': 'zona es de compras voy a comprar y ellos',
#   'start': 985.56,
#   'duration': 4.24},
#  {'text': 'van a vender y me van a tirar el precio',
#   'start': 988.16,
#   'duration': 4.359},
#  {'text': 'y me pueden pillar el Stop pues me lo',
#   'start': 989.8,
#   'duration': 4.839},
#  {'text': 'planteo para eso sirven también los',
#   'start': 992.519,
#   'duration': 3.841},
#  {'text': 'niveles intr diarios yo los utilizo',
#   'start': 994.639,
#   'duration': 4.88},
#  {'text': 'mucho para eso ven se colocaría aquí se',
#   'start': 996.36,
#   'duration': 6.039},
#  {'text': 'podría encontrar esa oposición por las',
#   'start': 999.519,
#   'duration': 6.56},
#  {'text': 'ventas eso en el caso de que sea alcista',
#   'start': 1002.399,
#   'duration': 4.68},
#  {'text': 'Al Día de', 'start': 1006.079, 'duration': 3.601},
#  {'text': 'momento se está vendiendo está por',
#   'start': 1007.079,
#   'duration': 4.841},
#  {'text': 'debajo del eje central de operaciones',
#   'start': 1009.68,
#   'duration': 4.56},
#  {'text': '10473 llegado al primer nivel',
#   'start': 1011.92,
#   'duration': 4.719},
#  {'text': '10337 el segundo', 'start': 1014.24, 'duration': 8.44},
#  {'text': '10369 10316 26 Y por último', 'start': 1016.639, 'duration': 9.241},
#  {'text': '10642 Y con quién coincide este',
#   'start': 1022.68,
#   'duration': 6.279},
#  {'text': 'nivel con el objetivo de mediano plazo y',
#   'start': 1025.88,
#   'duration': 4.76},
#  {'text': 'con la apertura de esta semana están',
#   'start': 1028.959,
#   'duration': 5.761},
#  {'text': 'todos aquí sería una zona de', 'start': 1030.64, 'duration': 7.0},
#  {'text': 'freno para parar la caída buscando',
#   'start': 1034.72,
#   'duration': 4.88},
#  {'text': 'liquidez en la apertura semanal en el',
#   'start': 1037.64,
#   'duration': 5.36},
#  {'text': 'mediano plazo y en este', 'start': 1039.6, 'duration': 3.4},
#  {'text': 'nivel bien pues ya sabemos Cuál es la',
#   'start': 1043.36,
#   'duration': 4.88},
#  {'text': 'negociación intr diaria ya sabemos Cuál',
#   'start': 1045.88,
#   'duration': 4.96},
#  {'text': 'es la que está sucediendo en 4',
#   'start': 1048.24,
#   'duration': 5.52},
#  {'text': 'horas y uno puede tomar determinaciones',
#   'start': 1050.84,
#   'duration': 6.04},
#  {'text': 'y tener plan si llega a un precio si',
#   'start': 1053.76,
#   'duration': 5.36},
#  {'text': 'compro si llega a otro si compraría más',
#   'start': 1056.88,
#   'duration': 4.88},
#  {'text': 'abajo cuando busquen liquidez o si',
#   'start': 1059.12,
#   'duration': 3.76},
#  {'text': 'incluso', 'start': 1061.76, 'duration': 3.52},
#  {'text': 'Eh quiero estar negociando aquí con',
#   'start': 1062.88,
#   'duration': 4.44},
#  {'text': 'ventas en corto cada uno puede',
#   'start': 1065.28,
#   'duration': 4.48},
#  {'text': 'establecer su plan Esta es la forma de',
#   'start': 1067.32,
#   'duration': 3.92},
#  {'text': 'ver el mercado con la acción del precio',
#   'start': 1069.76,
#   'duration': 4.039},
#  {'text': 'y los niveles calculados un día en el',
#   'start': 1071.24,
#   'duration': 5.6},
#  {'text': 'que el sentimiento de', 'start': 1073.799, 'duration': 5.601},
#  {'text': 'Mercado ha subido un punto en las',
#   'start': 1076.84,
#   'duration': 5.52},
#  {'text': 'acciones pero que en el mundo cripto de',
#   'start': 1079.4,
#   'duration': 5.6},
#  {'text': 'repente se ha puesto a seis puntos más',
#   'start': 1082.36,
#   'duration': 5.16},
#  {'text': 'arriba con respecto a', 'start': 1085.0, 'duration': 6.84},
#  {'text': 'ayer curioso verdad cuando nos muestra',
#   'start': 1087.52,
#   'duration': 8.72},
#  {'text': 'el BX que en el', 'start': 1091.84, 'duration': 9.16},
#  {'text': 'mercado stock Index de las acciones no',
#   'start': 1096.24,
#   'duration': 7.799},
#  {'text': 'hay de momento no muestra ningún tipo de',
#   'start': 1101.0,
#   'duration': 7.12},
#  {'text': 'preocupación antes de pasar a las otras',
#   'start': 1104.039,
#   'duration': 6.721},
#  {'text': 'criptomonedas quiero que vean como el',
#   'start': 1108.12,
#   'duration': 5.28},
#  {'text': 'sp500 en el día de hoy los futuros nos',
#   'start': 1110.76,
#   'duration': 5.0},
#  {'text': 'están adelantando la subida hasta el',
#   'start': 1113.4,
#   'duration': 6.04},
#  {'text': 'objetivo de los 6119 este objetivo',
#   'start': 1115.76,
#   'duration': 6.88},
#  {'text': 'habíamos hablado ayer que estando las',
#   'start': 1119.44,
#   'duration': 4.88},
#  {'text': 'cosas como estaban después del señor',
#   'start': 1122.64,
#   'duration': 3.96},
#  {'text': 'poell pues que aquí había una operación',
#   'start': 1124.32,
#   'duration': 4.32},
#  {'text': 'de muy corto plazo para atacar los',
#   'start': 1126.6,
#   'duration': 5.4},
#  {'text': '6119 ahí la tiene también dijimos que en',
#   'start': 1128.64,
#   'duration': 5.12},
#  {'text': 'el', 'start': 1132.0, 'duration': 4.88},
#  {'text': 'nasdaq con el con la liquidez que',
#   'start': 1133.76,
#   'duration': 5.84},
#  {'text': 'encontró desde el 28 de las palabras del',
#   'start': 1136.88,
#   'duration': 5.52},
#  {'text': 'señor pell el sentimiento del mercado',
#   'start': 1139.6,
#   'duration': 4.76},
#  {'text': 'con el que abrió ayer estamos viendo que',
#   'start': 1142.4,
#   'duration': 5.0},
#  {'text': 'los futuros hoy adelantan también y lo',
#   'start': 1144.36,
#   'duration': 5.24},
#  {'text': 'mismo dijimos Bueno pues el precio se',
#   'start': 1147.4,
#   'duration': 3.72},
#  {'text': 'está moviendo entre la apertura del año',
#   'start': 1149.6,
#   'duration': 4.52},
#  {'text': 'y los 2183 le falta poco para', 'start': 1151.12, 'duration': 5.6},
#  {'text': 'llegar que incluso tiene niveles intr',
#   'start': 1154.12,
#   'duration': 4.48},
#  {'text': 'diarios para llegar ahí en el día de hoy',
#   'start': 1156.72,
#   'duration': 4.6},
#  {'text': 'están viendo que perfectamente podría',
#   'start': 1158.6,
#   'duration': 4.439},
#  {'text': 'llegar el precio', 'start': 1161.32, 'duration': 6.239},
#  {'text': '22171 puntos y aquí lo que tenemos como',
#   'start': 1163.039,
#   'duration': 6.961},
#  {'text': 'objetivo', 'start': 1167.559, 'duration': 5.321},
#  {'text': '21,83 O sea que se quedaría está muy',
#   'start': 1170.0,
#   'duration': 5.72},
#  {'text': 'cerquita ya o sea hay oportunidades el',
#   'start': 1172.88,
#   'duration': 6.2},
#  {'text': 'mercado de las acciones no está con una',
#   'start': 1175.72,
#   'duration': 6.4},
#  {'text': 'preocupación sigue subiendo vamos a ver',
#   'start': 1179.08,
#   'duration': 5.959},
#  {'text': 'qué pasa entonces con ethereum porque',
#   'start': 1182.12,
#   'duration': 4.6},
#  {'text': 'etherium también ha encontrado esa',
#   'start': 1185.039,
#   'duration': 4.281},
#  {'text': 'liquidez en la zona a la que se caía',
#   'start': 1186.72,
#   'duration': 7.319},
#  {'text': 'dijimos aquí podría encontrar 342 y está',
#   'start': 1189.32,
#   'duration': 6.96},
#  {'text': 'y también ahora en el 50% de esta',
#   'start': 1194.039,
#   'duration': 5.321},
#  {'text': 'corrección anterior de la fase una está',
#   'start': 1196.28,
#   'duration': 5.48},
#  {'text': 'intentando hacer una fase tres este',
#   'start': 1199.36,
#   'duration': 4.76},
#  {'text': 'movimiento que se está propiciando de',
#   'start': 1201.76,
#   'duration': 4.279},
#  {'text': 'mínimos crecientes y de máximos',
#   'start': 1204.12,
#   'duration': 5.679},
#  {'text': 'crecientes podría ser una fase tres está',
#   'start': 1206.039,
#   'duration': 5.64},
#  {'text': 'intentando romper por primera vez esta',
#   'start': 1209.799,
#   'duration': 5.681},
#  {'text': 'directriz si se fijan Y eso en caso de',
#   'start': 1211.679,
#   'duration': 6.841},
#  {'text': 'colocarse el precio por esta zona Aquí',
#   'start': 1215.48,
#   'duration': 6.199},
#  {'text': 'sí que se abriría empezaría a abrirse la',
#   'start': 1218.52,
#   'duration': 5.24},
#  {'text': 'puerta a', 'start': 1221.679, 'duration': 5.601},
#  {'text': 'muchos especuladores inversores para',
#   'start': 1223.76,
#   'duration': 6.56},
#  {'text': 'llegar en corto plazo Mira los 3664',
#   'start': 1227.28,
#   'duration': 4.879},
#  {'text': 'volverlo a atacar', 'start': 1230.32, 'duration': 4.44},
#  {'text': '3997 en fin hay para todos los gustos',
#   'start': 1232.159,
#   'duration': 5.481},
#  {'text': 'los de ya van mediano plazo serían los',
#   'start': 1234.76,
#   'duration': 4.96},
#  {'text': 'que van negociando a las los objetivos',
#   'start': 1237.64,
#   'duration': 5.08},
#  {'text': 'naranjas y este que sería el de la fase',
#   'start': 1239.72,
#   'duration': 5.0},
#  {'text': 'tres este estaríamos hablando también de',
#   'start': 1242.72,
#   'duration': 3.72},
#  {'text': 'mediano plazo entre corto y mediano',
#   'start': 1244.72,
#   'duration': 4.439},
#  {'text': 'plazo 4608 hablo cuando hablo de mediano',
#   'start': 1246.44,
#   'duration': 5.239},
#  {'text': 'plazo es en dentro del año el año',
#   'start': 1249.159,
#   'duration': 4.321},
#  {'text': 'empieza el 1 de enero y acaba el 31 de',
#   'start': 1251.679,
#   'duration': 3.841},
#  {'text': 'diciembre ahí establezco el mediano',
#   'start': 1253.48,
#   'duration': 3.559},
#  {'text': 'plazo', 'start': 1255.52, 'duration': 4.159},
#  {'text': 'vale si dura las pocas semanas y llega a',
#   'start': 1257.039,
#   'duration': 4.441},
#  {'text': 'objetivos de mediano plazo pues se está',
#   'start': 1259.679,
#   'duration': 4.601},
#  {'text': 'aprovechando en el corto plazo pues está',
#   'start': 1261.48,
#   'duration': 5.16},
#  {'text': 'muy bien Vamos a ver si lo consigue voy',
#   'start': 1264.28,
#   'duration': 5.04},
#  {'text': 'a extenderla voy a seguir extendiéndola',
#   'start': 1266.64,
#   'duration': 4.56},
#  {'text': 'porque está intentando romperla ahora',
#   'start': 1269.32,
#   'duration': 3.64},
#  {'text': 'mismo está ahí detenido el precio vamos',
#   'start': 1271.2,
#   'duration': 2.44},
#  {'text': 'a', 'start': 1272.96, 'duration': 3.599},
#  {'text': 'mirarlo fantástico está ahí intentando',
#   'start': 1273.64,
#   'duration': 5.72},
#  {'text': 'romperlo esta directriz bajista con esos',
#   'start': 1276.559,
#   'duration': 5.161},
#  {'text': 'con el último pivot máximo decreciente',
#   'start': 1279.36,
#   'duration': 5.52},
#  {'text': 'los alumnos de crc Trader que por cierto',
#   'start': 1281.72,
#   'duration': 5.88},
#  {'text': 'Ya acabaron ayer su edición ahora quedan',
#   'start': 1284.88,
#   'duration': 5.36},
#  {'text': 'ya unos días para empezar la de febrero',
#   'start': 1287.6,
#   'duration': 5.559},
#  {'text': 'y van quedando últimos días y últimas',
#   'start': 1290.24,
#   'duration': 4.24},
#  {'text': 'plazas y además también tienen la',
#   'start': 1293.159,
#   'duration': 4.201},
#  {'text': 'oportunidad de ver en grabado la la',
#   'start': 1294.48,
#   'duration': 4.799},
#  {'text': 'masterclass de refugios de largo y de',
#   'start': 1297.36,
#   'duration': 4.28},
#  {'text': 'mediano plazo Bueno pues esta es la',
#   'start': 1299.279,
#   'duration': 4.441},
#  {'text': 'situación en eterio está muy interesante',
#   'start': 1301.64,
#   'duration': 3.96},
#  {'text': 'niveles intr diarios para la', 'start': 1303.72, 'duration': 4.319},
#  {'text': 'jornada', 'start': 1305.6, 'duration': 4.959},
#  {'text': '3247 el eje central de operaciones ha',
#   'start': 1308.039,
#   'duration': 5.841},
#  {'text': 'caído hacia la apertura vamos a abrirlo',
#   'start': 1310.559,
#   'duration': 5.521},
#  {'text': 'hacia la apertura semanal que está en',
#   'start': 1313.88,
#   'duration': 3.08},
#  {'text': 'los', 'start': 1316.08, 'duration': 3.68},
#  {'text': '3,228 y al segundo objetivo y aquí he',
#   'start': 1316.96,
#   'duration': 5.0},
#  {'text': 'encontrado automáticamente liquidez en',
#   'start': 1319.76,
#   'duration': 2.84},
#  {'text': 'los', 'start': 1321.96, 'duration': 4.92},
#  {'text': '3215 todavía le quedan 3182 y 3195 vemos',
#   'start': 1322.6,
#   'duration': 7.6},
#  {'text': 'que subió también ha ido en el día de',
#   'start': 1326.88,
#   'duration': 5.44},
#  {'text': 'hoy al segundo objetivo por arriba',
#   'start': 1330.2,
#   'duration': 6.479},
#  {'text': '3280 pero miren ustedes lo que está',
#   'start': 1332.32,
#   'duration': 6.76},
#  {'text': 'pasando voy a voy a escoger estos',
#   'start': 1336.679,
#   'duration': 5.681},
#  {'text': 'últimos Para que vean Cómo es cómo puede',
#   'start': 1339.08,
#   'duration': 5.839},
#  {'text': 'ser el principio de una reversión porque',
#   'start': 1342.36,
#   'duration': 5.08},
#  {'text': 'está es ahora mismo lo que nos está est',
#   'start': 1344.919,
#   'duration': 6.201},
#  {'text': 'otro no está aquí pero esto sería la',
#   'start': 1347.44,
#   'duration': 6.28},
#  {'text': 'posibilidad de que los máximos ya se han',
#   'start': 1351.12,
#   'duration': 6.84},
#  {'text': 'ido acercando ya vemos los como los',
#   'start': 1353.72,
#   'duration': 7.12},
#  {'text': 'pivot máximos el anterior estaba aquí se',
#   'start': 1357.96,
#   'duration': 4.76},
#  {'text': 'están acercando y está pareciendo que',
#   'start': 1360.84,
#   'duration': 3.68},
#  {'text': 'quiere revertir si', 'start': 1362.72, 'duration': 4.12},
#  {'text': 'revierte el hecho de que haya subido',
#   'start': 1364.52,
#   'duration': 4.759},
#  {'text': 'aquí no es otra cosa que posibilidad de',
#   'start': 1366.84,
#   'duration': 5.12},
#  {'text': 'pullback hacia la zona y 3182 vamos a',
#   'start': 1369.279,
#   'duration': 6.601},
#  {'text': 'ver cómo va eso ocurriría algo con',
#   'start': 1371.96,
#   'duration': 5.24},
#  {'text': 'respecto a lo que estamos viendo en la',
#   'start': 1375.88,
#   'duration': 3.52},
#  {'text': 'serie diaria si pasa eso no es normal',
#   'start': 1377.2,
#   'duration': 5.28},
#  {'text': 'Porque además Ven por aquí hay quien',
#   'start': 1379.4,
#   'duration': 5.48},
#  {'text': 'está aprovechando para vender porque en',
#   'start': 1382.48,
#   'duration': 5.96},
#  {'text': 'cuanto toca Uy yo tengo aquí mi mi orden',
#   'start': 1384.88,
#   'duration': 6.36},
#  {'text': 'preparada como toque quien utiliza',
#   'start': 1388.44,
#   'duration': 4.479},
#  {'text': 'máximos y mínimos y quien Utiliza',
#   'start': 1391.24,
#   'duration': 4.4},
#  {'text': 'también los máximos y los mínimos para',
#   'start': 1392.919,
#   'duration': 6.24},
#  {'text': 'determinar una caída del precio que va',
#   'start': 1395.64,
#   'duration': 5.36},
#  {'text': 'saliendo así matemáticamente con una',
#   'start': 1399.159,
#   'duration': 3.76},
#  {'text': 'línea pero que lo podríamos ver',
#   'start': 1401.0,
#   'duration': 3.919},
#  {'text': 'perfectamente en una Excel como les dije',
#   'start': 1402.919,
#   'duration': 4.161},
#  {'text': 'al principio Bueno pues esta es la',
#   'start': 1404.919,
#   'duration': 4.161},
#  {'text': 'situación en ethereum', 'start': 1407.08, 'duration': 4.4},
#  {'text': 'acabamos ya viendo que', 'start': 1409.08, 'duration': 5.68},
#  {'text': 'xrp después de que ayer volvió a cerrar',
#   'start': 1411.48,
#   'duration': 6.0},
#  {'text': 'por encima del objetivo de los',
#   'start': 1414.76,
#   'duration': 5.72},
#  {'text': '387 voy a poner el trazo un poquito más',
#   'start': 1417.48,
#   'duration': 6.76},
#  {'text': 'fino ayer volví a cerrar por encima del',
#   'start': 1420.48,
#   'duration': 7.84},
#  {'text': '3087 del 312 objetivos automáticamente',
#   'start': 1424.24,
#   'duration': 5.76},
#  {'text': 'se están vendiendo y además por aquí',
#   'start': 1428.32,
#   'duration': 3.359},
#  {'text': 'pasa También esa directriz que teníamos',
#   'start': 1430.0,
#   'duration': 4.76},
#  {'text': 'punteada verdad Entonces si tenía si',
#   'start': 1431.679,
#   'duration': 5.321},
#  {'text': 'estaban determinando comprar han visto',
#   'start': 1434.76,
#   'duration': 4.72},
#  {'text': 'que habíamos hablado de cuidado porque',
#   'start': 1437.0,
#   'duration': 4.96},
#  {'text': 'se puede vender pero vamos a ver hasta',
#   'start': 1439.48,
#   'duration': 5.6},
#  {'text': 'dónde vamos a ver si ya no no pasa esto',
#   'start': 1441.96,
#   'duration': 6.48},
#  {'text': 'y empieza a aparecer aquí', 'start': 1445.08, 'duration': 5.599},
#  {'text': 'liquidez a medida de que están',
#   'start': 1448.44,
#   'duration': 4.92},
#  {'text': 'distribuyendo vamos a ver si se da la',
#   'start': 1450.679,
#   'duration': 4.081},
#  {'text': 'situación de que compren Porque si',
#   'start': 1453.36,
#   'duration': 3.72},
#  {'text': 'compran Entonces sería la zona donde',
#   'start': 1454.76,
#   'duration': 4.399},
#  {'text': 'podría volver ese', 'start': 1457.08, 'duration': 4.36},
#  {'text': 'ataque Pero se tiene que dar para que',
#   'start': 1459.159,
#   'duration': 4.12},
#  {'text': 'haya ese plan de compra para ir a los',
#   'start': 1461.44,
#   'duration': 3.44},
#  {'text': '333', 'start': 1463.279, 'duration': 5.561},
#  {'text': 'y 374 416', 'start': 1464.88, 'duration': 6.64},
#  {'text': 'para eso tiene que darse esa y todavía',
#   'start': 1468.84,
#   'duration': 5.16},
#  {'text': 'no se está dando verdad Ahora si aparece',
#   'start': 1471.52,
#   'duration': 7.92},
#  {'text': 'liquidez lo vamos a ver por último en',
#   'start': 1474.0,
#   'duration': 5.44},
#  {'text': 'solana que va en una fase tres vamos a',
#   'start': 1479.799,
#   'duration': 5.521},
#  {'text': 'ver si Termina de hacer aquí el Asa de',
#   'start': 1482.96,
#   'duration': 5.52},
#  {'text': 'taza y el precio recupera vamos a ver si',
#   'start': 1485.32,
#   'duration': 4.959},
#  {'text': 'lo consigue incluso puede llegar a los',
#   'start': 1488.48,
#   'duration': 4.319},
#  {'text': '217 a buscar esa liquidez ahora mismo',
#   'start': 1490.279,
#   'duration': 5.081},
#  {'text': 'está aquí en medio vamos a ver si lo',
#   'start': 1492.799,
#   'duration': 4.521},
#  {'text': 'consigue si', 'start': 1495.36, 'duration': 4.799},
#  {'text': 'no como ya he llegado al primer objetivo',
#   'start': 1497.32,
#   'duration': 5.32},
#  {'text': 'de la de la sabes que la estrategia',
#   'start': 1500.159,
#   'duration': 4.12},
#  {'text': 'tendencial sería ese que dice ahí arriba',
#   'start': 1502.64,
#   'duration': 6.519},
#  {'text': '125 por a ese ha llegado en caso de que',
#   'start': 1504.279,
#   'duration': 8.52},
#  {'text': 'siga el precio entrando y no consiga ser',
#   'start': 1509.159,
#   'duration': 5.321},
#  {'text': 'un aa de tasa sino que caiga hacia al',
#   'start': 1512.799,
#   'duration': 6.561},
#  {'text': '6180 los 8 entonces todo sería una fase',
#   'start': 1514.48,
#   'duration': 7.559},
#  {'text': 'mayor con tres fases', 'start': 1519.36, 'duration': 5.6},
#  {'text': 'menores vale se quedarían como momentos',
#   'start': 1522.039,
#   'duration': 4.76},
#  {'text': 'de Mercado y empezaríamos con una gran',
#   'start': 1524.96,
#   'duration': 5.24},
#  {'text': 'fase una y dos lo mismo da da lo mismo',
#   'start': 1526.799,
#   'duration': 4.801},
#  {'text': 'pero sería muy interesante que aquí se',
#   'start': 1530.2,
#   'duration': 4.32},
#  {'text': 'dibuje el Asa de tasa que sería esto y',
#   'start': 1531.6,
#   'duration': 3.799},
#  {'text': 'que el', 'start': 1534.52, 'duration': 3.68},
#  {'text': 'precio rápidamente vuelva a salir en',
#   'start': 1535.399,
#   'duration': 5.4},
#  {'text': 'busca de los 287 donde nunca ha cerrado',
#   'start': 1538.2,
#   'duration': 5.44},
#  {'text': 'por encima Por eso tengo esta proyección',
#   'start': 1540.799,
#   'duration': 4.721},
#  {'text': 'como más probable vamos a ver si se da',
#   'start': 1543.64,
#   'duration': 3.84},
#  {'text': 'ya el ataque de los siguientes niveles',
#   'start': 1545.52,
#   'duration': 3.6},
#  {'text': 'Pero se tiene que dar pero esa es la',
#   'start': 1547.48,
#   'duration': 4.04},
#  {'text': 'proyección que tengo porque el precio no',
#   'start': 1549.12,
#   'duration': 5.559},
#  {'text': 'cerró solo salió rechazado con ventas',
#   'start': 1551.52,
#   'duration': 8.159},
#  {'text': 'aquí con stop profit no con top',
#   'start': 1554.679,
#   'duration': 8.6},
#  {'text': 'Close que es el importante bueno con',
#   'start': 1559.679,
#   'duration': 5.201},
#  {'text': 'todo esto con lo que está pasando en',
#   'start': 1563.279,
#   'duration': 4.88},
#  {'text': 'bitcoin hoy vamos a dejarlo por aquí',
#   'start': 1564.88,
#   'duration': 5.56},
#  {'text': 'sigue estando por debajo de ese 6180 de',
#   'start': 1568.159,
#   'duration': 4.041},
#  {'text': 'los niveles intr diarios Eso quiere',
#   'start': 1570.44,
#   'duration': 4.4},
#  {'text': 'decir que el escenario bajista es el que',
#   'start': 1572.2,
#   'duration': 6.16},
#  {'text': 'ahora mismo Está proyectado y validado',
#   'start': 1574.84,
#   'duration': 7.24},
#  {'text': 'en el día de hoy lo dejamos aquí',
#   'start': 1578.36,
#   'duration': 4.76},
#  {'text': 'seguimos', 'start': 1582.08, 'duration': 3.68},
#  {'text': 'después será más y mejor bueno seguimos',
#   'start': 1583.12,
#   'duration': 4.12},
#  {'text': 'después hoy es viernes normalmente solo',
#   'start': 1585.76,
#   'duration': 3.72},
#  {'text': 'tenemos un vídeo', 'start': 1587.24, 'duration': 4.0},
#  {'text': 'Pero ya sabes que en cualquier', 'start': 1589.48, 'duration': 3.6},
#  {'text': 'circunstancia si no yo en Telegram',
#   'start': 1591.24,
#   'duration': 3.12},
#  {'text': 'Siempre voy poniendo', 'start': 1593.08, 'duration': 5.12},
#  {'text': 'cositas de información eh No de Señales',
#   'start': 1594.36,
#   'duration': 6.76},
#  {'text': 'y no descarto hacer una alguna cosita',
#   'start': 1598.2,
#   'duration': 5.64},
#  {'text': 'mañana sábado así rapidita vamos a ver',
#   'start': 1601.12,
#   'duration': 5.159},
#  {'text': 'cómo se nos van dando las cosas de',
#   'start': 1603.84,
#   'duration': 4.12},
#  {'text': 'cualquier manera que tengas un gran fin',
#   'start': 1606.279,
#   'duration': 4.161},
#  {'text': 'de semana Será más y mejor Saludos',
#   'start': 1607.96,
#   'duration': 5.48},
#  {'text': 'cordiales', 'start': 1610.44, 'duration': 3.0}]

# %%
# !pip install --upgrade --quiet  

# PytubeError: Exception while accessing title of https://youtube.com/watch?v=TKCMw0utiak.
# Please file a bug report at https://github.com/pytube/pytube

# https://github.com/pytube/pytube/pull/2055/commits

#python -m pip install git+https://github.com/WildDIC/pytube.git

# %%
from langchain_community.document_loaders import YoutubeLoader

# %%
url = "https://www.youtube.com/watch?v=qiLYxZZC5KA"
loader = YoutubeLoader.from_youtube_url(url, add_video_info=False,language='es')

# %%
loader.video_id
# Out:
# 'qiLYxZZC5KA'

# %%
docs = loader.load()

# %%
doc = docs[0]

# %%
doc.metadata

len(doc.page_content)
# Out:
# 20961

# %%
### Read youtube video in 10 mins chunks
# 
from langchain_community.document_loaders.youtube import TranscriptFormat 

loader = YoutubeLoader.from_youtube_url(url, add_video_info=False, language="es",transcript_format=TranscriptFormat.CHUNKS, chunk_size_seconds=600)

# %%
docs = loader.load()

# %%
docs[2].metadata
# Out:
# {'source': 'https://www.youtube.com/watch?v=qiLYxZZC5KA&t=1200s',
#  'start_seconds': 1200,
#  'start_timestamp': '00:20:00'}

# %%
len(docs[2].page_content)//4
# Out:
# 1422

# %%
### Use LLM to generate youtube video keyword

# %%
from scripts import  llm

# %%
question = """You are an assistant for generating SEO keywords for YouTube.
            Please generate a list of keywords from the above context.
            You can use your creativity and correct spelling if it is needed."""

keywords = []
for doc in docs:
    kws = llm.ask_llm(context=doc.page_content, question=question)
    keywords.append(kws)

# %%
keywords = ", ".join(keywords)

# %%
print(keywords)
# Out:
# Based on the provided context, here are some relevant keywords that can be generated for YouTube SEO:
#
# 1. Bitcoin analysis
# 2. Ethereum analysis
# 3. XRP analysis
# 4. Solana analysis
# 5. Market trends
# 6. Technical analysis
# 7. Trading strategies
# 8. Price prediction
# 9. Technical indicators
# 10. Chart patterns
# 11. Market news
# 12. Financial markets
# 13. Cryptocurrency trading
# 14. Investing in Bitcoin
# 15. Ethereum investment tips
#
# Long-tail keywords:
#
# 1. "Bitcoin technical analysis"
# 2. "Ethereum price prediction"
# 3. "XRP market trends"
# 4. "Solana cryptocurrency analysis"
# 5. "Technical indicators for traders"
# 6. "Chart patterns in finance"
# 7. "Market news updates"
# 8. "Cryptocurrency trading strategies"
# 9. "Investing in Bitcoin explained"
# 10. "Ethereum investment tips and tricks"
#
# Keyword phrases:
#
# 1. "How to analyze the market"
# 2. "Technical analysis for beginners"
# 3. "Price prediction techniques"
# 4. "Chart patterns and their meaning"
# 5. "Market trends and analysis"
# 6. "Cryptocurrency trading strategies"
# 7. "Investing in Bitcoin vs Ethereum"
# 8. "Market news and updates"
#
# Note: These keywords can be used as titles, descriptions, or tags for YouTube videos related to the context provided., Based on the provided context, here are some relevant keywords that can be used for SEO optimization on YouTube:
#
# **Primary Keywords**
#
# 1. "Intraday analysis"
# 2. "Market trend prediction"
# 3. "Stock market analysis"
# 4. "Cryptocurrency trading tips"
# 5. "Technical analysis"
#
# **Secondary Keywords**
#
# 1. "Economy news"
# 2. "Financial markets"
# 3. "Investment strategies"
# 4. "Trading signals"
# 5. "Forex market analysis"
#
# **Long-Tail Keywords**
#
# 1. "How to trade cryptocurrencies"
# 2. "Intraday stock market analysis"
# 3. "Technical indicators for traders"
# 4. "Market sentiment analysis tools"
# 5. "Cryptocurrency price prediction models"
#
# **Keyword Phrases**
#
# 1. "Understanding intraday market trends"
# 2. "Technical analysis of cryptocurrency markets"
# 3. "Stock market analysis and predictions"
# 4. "Intraday trading strategies for beginners"
# 5. "How to use technical indicators in trading"
#
# These keywords can be used as titles, descriptions, or tags for YouTube videos related to the provided context., Based on the provided context, here's a list of relevant keywords that can be used for SEO optimization in a YouTube video:
#
# 1. Ethereum
# 2. Bitcoin
# 3. Crypto market analysis
# 4. Technical analysis
# 5. Trend following
# 6. Swing trading
# 7. Day trading
# 8. Intraday analysis
# 9. Pivot points
# 10. Support and resistance levels
# 11. Liquidity
# 12. Market trends
# 13. FOMO (Fear of Missing Out)
# 14. Risk management
# 15. Position sizing
# 16. Market sentiment
# 17. Crypto news
# 18. Trading strategies
# 19. Asa de taza (a trading strategy)
# 20. Tasa y precio (price and time in Spanish)
# 21. Fase tres (phase three in Spanish)
# 22. Pullback
# 23. Reversión
# 24. Trading psychology
# 25. Market forecasting
#
# Some long-tail keywords that can be used:
#
# 1. Ethereum market analysis
# 2. Bitcoin trading strategies
# 3. Technical analysis for crypto traders
# 4. Swing trading tips and tricks
# 5. Day trading ideas for beginners
# 6. Intraday analysis and technical indicators
# 7. Crypto trend following
# 8. Market sentiment analysis tools
#
# Note that this list is not exhaustive, and more keywords can be generated based on the specific topic of the YouTube video.

# %%
question = """Above context is the list of relevant keywords for a YouTube video.
                You need to generate SEO Keywords for it."""

response = llm.ask_llm(context=keywords, question=question)

# %%
print(response)
# Out:
# I don't know. The provided context doesn't specify the exact title or topic of the YouTube video, which makes it challenging to generate specific SEO keywords. However, based on the general theme of "Cryptocurrency trading" and "Technical analysis," here are some possible keyword phrases:
#
# **Primary Keywords**
#
# 1. "Crypto trading strategies"
# 2. "Technical analysis for cryptocurrency traders"
# 3. "Intraday crypto market analysis"
#
# **Secondary Keywords**
#
# 1. "Swing trading tips"
# 2. "Day trading ideas for beginners"
# 3. "Market sentiment analysis tools"
#
# **Long-Tail Keywords**
#
# 1. "How to use technical indicators in cryptocurrency trading"
# 2. "Crypto trend following strategies"
# 3. "Intraday analysis and chart patterns for crypto traders"
#
# **Keyword Phrases**
#
# 1. "Understanding crypto market trends"
# 2. "Technical analysis of cryptocurrency markets"
# 3. "Swing trading vs day trading"
#
# Please provide more context or information about the YouTube video to generate more specific SEO keywords.
